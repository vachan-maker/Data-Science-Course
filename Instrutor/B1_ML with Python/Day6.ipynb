# %% [markdown]
# **Machine Learning**: Machines using data to make accurate predictions or decisions.
#
# If i teach a child to recognize dogs,
#
# * child: **algorithm**
# * dog images/videos : **data**
# * learning process: **training**

# %% [markdown]
# # **Machine Learning Lifecycle**
#
# 1. Define the problem
# 2. Data Collection
# 3. Data Preparation
# 4. Model Development
# 5. Model Evaluation
# 6. Model Deployment
#
# In reality, the model lifecycle is iterative, which means that we tend to go back and forth between these processes.
#
# For example, if you find some problems with your models that are deployed in production,you may need to go back to data collection, or even the problem definition step, and then
# re-iterate the subsequent processes.
#
# Data collection and preparation is called the **Extract, Transform, and Load, or ETL process**.
#
# The **ETL process** involves collecting data from various sources,
# then cleaning, transforming, and storing it into a new single place.
#
# The data is then accessible to the machine learning engineer, allowing them to perform tasks like building a machine learning model.

# %% [markdown]
# Welcome to this introductory course on Machine Learning
#
# In today's class, you will explore fundamental concepts behind machine learning

# %% [markdown]
# #What is Exploratory Data Analysis?
# Exploratory Data Analysis is one of the main components of the Data Science Life Cycle, it is a technique to understand the various aspects of the data. For performing Exploratory Data Analysis (EDA) with python, you will need to get your hands on python’s libraries such as Pandas, NumPy, Matplotlib & Seaborn. Pandas is used for data exploration while matplotlib & Seaborn are used for plotting the data set to get more insights from the data.

# %% [markdown]
# ## DataFrame Built-In Functions
# * **`.head()`** shows up 5 records from top.
#
# * **`.tail()`** prints 5 records from bottom.
#
# * **`.shape()`** tells the shape of the dataset in the form of the number of rows and number of columns
#
# * **`.describe()`** describes the details of the dataset.

# %% [markdown]
# ## Import Libraries
# The first step of exploring any dataset is to import the required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Upload the Dataset
# Pandas is the library used to upload the data and data manipulation
#
# Working on: [Cars Dataset](https://www.kaggle.com/datasets/CooperUnion/cardataset?resource=download)
#
# To give a piece of brief information about the data set this data contains more of 10, 000 rows and more than 10 columns which contains features of the car such as Engine Fuel Type, Engine HP, Transmission Type, highway MPG, city MPG and many more.

# %%
cars = pd.read_csv('/content/car_details.csv')

# %%
#view the top 3 rows
cars.head(3)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# ...

# %%
#last 4 rows of the dataset
cars.tail(4)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# ...

# %%
# what are the different columns
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# information of all columns
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
# statistical details about numerical columns
cars.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
# statistical details of object type columns
cars.describe(include='object')
# Out:
#              Make           Model  Engine Fuel Type Transmission Type  \
# count       11914           11914             11911             11914
# unique         48             915                10                 5
# top     Chevrolet  Silverado 1500  regular unleaded         AUTOMATIC
# freq         1123             156              7172              8266
#
#             Driven_Wheels Market Category Vehicle Size Vehicle Style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front wheel drive       Crossover      Compact         Sedan
# freq                 4787            1110         4764          3048

# %%
#find out the count of different Makes of cars
cars.Make.value_counts()
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
#find out the count of different Vehicle Style of cars
cars['Vehicle Style'].value_counts()
# Out:
# Vehicle Style
# Sedan                  3048
# 4dr SUV                2488
# Coupe                  1211
# Convertible             793
# 4dr Hatchback           702
# Crew Cab Pickup         681
# Extended Cab Pickup     623
# Wagon                   592
# 2dr Hatchback           506
# Passenger Minivan       417
# Regular Cab Pickup      392
# 2dr SUV                 138
# Passenger Van           128
# Cargo Van                95
# Cargo Minivan            71
# Convertible SUV          29
# Name: count, dtype: int64

# %%
#find out the count of Transmission Type
cars['Transmission Type'].value_counts()
# Out:
# Transmission Type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
# to create a pie chart to show the count of Transmission Type
cars['Transmission Type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# to create a pie chart of the Engine Fuel Type
plt.figure(figsize=(8,6))
cars['Engine Fuel Type'].value_counts().plot(kind='pie')
plt.show()

# %%
# plot a bar plot between Engine Fuel type and MSRP
plt.figure(figsize=(20,6))
sns.barplot(y='Engine Fuel Type', x='MSRP', data=cars,palette='Set2')
plt.show()
# Out:
# <ipython-input-24-25fa796fcd03>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Engine Fuel Type', x='MSRP', data=cars,palette='Set2')

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# Boxplot between 'Engine HP' and 'Engine Cylinders'
plt.figure(figsize=(20,6))
sns.boxplot(y='Engine HP', x='Engine Cylinders', data=cars,palette='Set1')
plt.show()
# Out:
# <ipython-input-27-e1a1009d22cb>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='Engine HP', x='Engine Cylinders', data=cars,palette='Set1')

# %%
#how many cars have Engine Cylinders =0
cars[cars['Engine Cylinders']==0]['Engine Fuel Type'].value_counts()
# Out:
# Engine Fuel Type
# electric    56
# Name: count, dtype: int64

# %%
# Which cars have ngine Cylinders = 16
cars[cars['Engine Cylinders']==16]['Make'].value_counts()
# Out:
# Make
# Bugatti    3
# Name: count, dtype: int64

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# Value counts of Driven Wheels
sns.countplot(x='Driven_Wheels', data=cars, palette = 'viridis')
# Out:
# <ipython-input-33-7d5b0aa954f5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Driven_Wheels', data=cars, palette = 'viridis')
# <Axes: xlabel='Driven_Wheels', ylabel='count'>

# %%
# Value counts of Year
sns.countplot(y='Year', data=cars, palette = 'viridis')
# Out:
# <ipython-input-35-79af7c24c25d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Year', data=cars, palette = 'viridis')
# <Axes: xlabel='count', ylabel='Year'>

# %%
cars['Vehicle Size'].value_counts()
# Out:
# Vehicle Size
# Compact    4764
# Midsize    4373
# Large      2777
# Name: count, dtype: int64

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# countplot of 'Vehicle Style'
sns.countplot(y='Vehicle Style', data=cars, palette = 'viridis')
# Out:
# <ipython-input-39-ffedec5a3bd0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Vehicle Style', data=cars, palette = 'viridis')
# <Axes: xlabel='count', ylabel='Vehicle Style'>

# %%
# Fuel Consumption
sns.histplot(data=cars, x='highway MPG',hue='Engine Cylinders', multiple='stack', palette = 'inferno')
plt.xlim([0,80])  #limits the x-axis
# Out:
# (0.0, 80.0)

# %%
sns.scatterplot(data=cars,y='city mpg',x='highway MPG',hue='Engine Cylinders', palette = 'inferno')

#for non-electric cars
#plt.xlim([0,60])
#plt.ylim([0,60])

#for electric
plt.xlim([60,150])
plt.ylim([60,150])
# Out:
# (60.0, 150.0)

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
#grouping the dataframe based on 'Make'
cars['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
brand = cars.groupby(by='Make')['MSRP'].mean().sort_values(ascending=False)

# Step1 :  Grouping by 'Make' (object dtype)
# Step 2:  for each 'Make', you will find the mean MSRP (numerical dtype)
# Step 3:  Sort it in descending order

#convert this to a dataframe
brand_df=pd.DataFrame(brand)

#barplot the Make vs MSRP
plt.figure(figsize=(15,15))
sns.barplot(data=brand_df, y=brand_df.index, x='MSRP', palette='inferno')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-62-a1b764af3f37>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=brand_df, y=brand_df.index, x='MSRP', palette='inferno')

# %%
# Find number of cars that are of 'Make'=Ford
ford_cars = cars[cars['Make']== 'Ford']
ford_cars
# Out:
#        Make     Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1331   Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1332   Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1333   Ford  Aerostar  1995  regular unleaded      155.0               6.0
# 1334   Ford  Aerostar  1995  regular unleaded      135.0               6.0
# 1335   Ford  Aerostar  1996  regular unleaded      140.0               6.0
# ...     ...       ...   ...               ...        ...               ...
# 11443  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11444  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11445  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11446  Ford  Windstar  2003  regular unleaded      200.0               6.0
# 11447  Ford  Windstar  2003  regular unleaded      200.0               6.0
#
# ...

# %%
# group the Ford dataset by Year to filter out the unique car models manufactured per year

# Group by : Year    and display unique Models

ford_cars.groupby(by='Year')['Model'].unique()
# Out:
# Year
# 1990                      [Bronco II, LTD Crown Victoria]
# 1991                        [Festiva, LTD Crown Victoria]
# 1992                                     [Festiva, Tempo]
# 1993                                     [Festiva, Tempo]
# 1994                                      [Bronco, Tempo]
# 1995    [Aerostar, Aspire, Bronco, F-150 SVT Lightning...
# 1996      [Aerostar, Aspire, Bronco, E-150, E-250, Probe]
# 1997    [Aerostar, Aspire, E-150, E-250, F-250, Mustan...
# 1998    [Contour SVT, Contour, E-150, E-250, F-250, Mu...
# 1999    [Contour SVT, Contour, F-150 SVT Lightning, F-...
# 2000          [Contour SVT, Contour, F-150 SVT Lightning]
# 2001    [Escort, Explorer Sport, Windstar Cargo, Winds...
# 2002    [Escort, Explorer Sport, Windstar Cargo, Winds...
# 2003    [Escort, Explorer Sport, Thunderbird, Windstar...
# 2004                        [F-150 Heritage, Thunderbird]
# 2005    [Five Hundred, Freestar, Freestyle, GT, Thunde...
# ...

# %%
Comapritive analysis on Ford and BMW to find out:
1. Which Wheel drive was preferred over the years
2. Which Engine Cylinders were preferred over the years
3. Vehicle size changes
4. Engien Fuel Type
