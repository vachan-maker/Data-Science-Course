# %% [markdown]
# #**Day 3: Practice Session**

# %% [markdown]
# Dataset: IMdb dataset

# %%
import pandas as pd

# %%
#Read the csv file into python
movies_df = pd.read_csv('/content/IMDB-Movie-Data.csv',index_col='Title')

# %%
movies_df.head(5)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
#the last 5 rows in the dataset
movies_df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
# general information about the dataset including dtypes, non-null values.etc
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 126.0+ KB

# %%
movies_df.shape
# Out:
# (1000, 11)

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
#know more abou the statistical info in each numerical column
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
#to understand object-type columns:
movies_df.describe(include='object')
# Out:
#                           Genre  \
# count                      1000
# unique                      207
# top     Action,Adventure,Sci-Fi
# freq                         50
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A group of intergalactic criminals are forced ...  Ridley Scott
# freq                                                    1             8
#
#                                                    Actors
# count                                                1000
# unique                                                996
# top     Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...
# freq                                                    2

# %%
movies_df['Genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
movies_df['Actors'].describe()
# Out:
# count                                                  1000
# unique                                                  996
# top       Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...
# freq                                                      2
# Name: Actors, dtype: object

# %%
# To extract frequency of values in a column==> value_counts()
movies_df['Genre'].value_counts()
# Out:
# Genre
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Action,Comedy,Family        1
# Action,Crime,Fantasy        1
# Comedy,Mystery              1
# Adventure,Comedy,Horror     1
# Comedy,Family,Fantasy       1
# Name: count, Length: 207, dtype: int64

# %% [markdown]
# To extract a column from the dataframe:

# %%
genre_col=movies_df['Genre']
type(genre_col)
# Out:
# pandas.core.series.Series

# %%
# to extract a column as a dataframe: you will need to pass a list of columns []
genre_col = movies_df[['Genre']]
type(genre_col)
# Out:
# pandas.core.frame.DataFrame

# %%
# since its a list, adding another column name is easy:
subset_df = movies_df[['Genre','Actors']]
subset_df.head(2)
# Out:
#                                             Genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
#
#                                                                     Actors
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...

# %%
# create a subset df with columns: Genre, 'Rating', 'Revenue (Millions) and display the first 13 values and last 9 values

# %% [markdown]
# Row-wise Manipulation:
#
# 1. ```.loc```  : locates a row by name
# 2. `.iloc`  : locates by numerical index

# %%
movies_df.loc['Guardians of the Galaxy']
# Out:
# Rank                                                                  1
# Genre                                           Action,Adventure,Sci-Fi
# Description           A group of intergalactic criminals are forced ...
# Director                                                     James Gunn
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                               2014
# Runtime (Minutes)                                                   121
# Rating                                                              8.1
# Votes                                                            757074
# Revenue (Millions)                                               333.13
# Metascore                                                          76.0
# Name: Guardians of the Galaxy, dtype: object

# %%
movies_df.loc['Avatar']
# Out:
# Rank                                                                 88
# Genre                                          Action,Adventure,Fantasy
# Description           A paraplegic marine dispatched to the moon Pan...
# Director                                                  James Cameron
# Actors                Sam Worthington, Zoe Saldana, Sigourney Weaver...
# Year                                                               2009
# Runtime (Minutes)                                                   162
# Rating                                                              7.8
# Votes                                                            935408
# Revenue (Millions)                                               760.51
# Metascore                                                          83.0
# Name: Avatar, dtype: object

# %%
movies_df.iloc[87]  # iloc: locate by numerical index
# Out:
# Rank                                                                 88
# Genre                                          Action,Adventure,Fantasy
# Description           A paraplegic marine dispatched to the moon Pan...
# Director                                                  James Cameron
# Actors                Sam Worthington, Zoe Saldana, Sigourney Weaver...
# Year                                                               2009
# Runtime (Minutes)                                                   162
# Rating                                                              7.8
# Votes                                                            935408
# Revenue (Millions)                                               760.51
# Metascore                                                          83.0
# Name: Avatar, dtype: object

# %%
movies_df.iloc[0:4]  #movies from index 0 upto 4(excluding)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
#
# ...

# %% [markdown]
# #Exercise:
#
# 1. Locate the row with details of movie 'Arrival'
# 2. Locate the row details of Row no 440 to 445

# %%
movies_df.loc['Arrival']
# Out:
# Rank                                                                 20
# Genre                                              Drama,Mystery,Sci-Fi
# Description           When twelve mysterious spacecraft appear aroun...
# Director                                               Denis Villeneuve
# Actors                Amy Adams, Jeremy Renner, Forest Whitaker,Mich...
# Year                                                               2016
# Runtime (Minutes)                                                   116
# Rating                                                              8.0
# Votes                                                            340798
# Revenue (Millions)                                                100.5
# Metascore                                                          81.0
# Name: Arrival, dtype: object

# %%
movies_df.iloc[440:446]
# Out:
#                            Rank                     Genre  \
# Title
# Oz the Great and Powerful   441  Adventure,Family,Fantasy
# Brooklyn                    442             Drama,Romance
# Coraline                    443  Animation,Family,Fantasy
# Blue Valentine              444             Drama,Romance
# The Thinning                445                  Thriller
# Silent Hill                 446  Adventure,Horror,Mystery
#
#                                                                  Description  \
# Title
# Oz the Great and Powerful  A frustrated circus magician from Kansas is tr...
# Brooklyn                   An Irish immigrant lands in 1950s Brooklyn, wh...
# Coraline                   An adventurous girl finds another world that i...
# Blue Valentine             The relationship of a contemporary married cou...
# The Thinning               "The Thinning" takes place in a post-apocalypt...
# Silent Hill                A woman, Rose, goes in search for her adopted ...
#
# ...

# %% [markdown]
# If i want to display details of separate rows at once:

# %%
# to extarct info from rows 0, 15 and 991

movies_df.iloc[[0,15,991]]
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# The Secret Life of Pets    16  Animation,Adventure,Comedy
# Taare Zameen Par          992          Drama,Family,Music
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# The Secret Life of Pets  The quiet life of a terrier named Max is upend...
# Taare Zameen Par         An eight-year-old boy is thought to be a lazy ...
#
#                              Director  \
# Title
# Guardians of the Galaxy    James Gunn
# The Secret Life of Pets  Chris Renaud
# Taare Zameen Par           Aamir Khan
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# The Secret Life of Pets  Louis C.K., Eric Stonestreet, Kevin Hart, Lake...
# ...

# %% [markdown]
# # To extract information based on conditions:

# %%
#print info of movies with rating greater than 8.5

#df_name[condition]     condition: df_name['Rating']>8.5
#df_name[df_name['Rating']>8.5]

movies_df[movies_df['Rating']>8.5]
# Out:
#                   Rank                    Genre  \
# Title
# Interstellar        37   Adventure,Drama,Sci-Fi
# The Dark Knight     55       Action,Crime,Drama
# Inception           81  Action,Adventure,Sci-Fi
# Kimi no na wa       97  Animation,Drama,Fantasy
# Dangal             118   Action,Biography,Drama
# The Intouchables   250   Biography,Comedy,Drama
#
#                                                         Description  \
# Title
# Interstellar      A team of explorers travel through a wormhole ...
# The Dark Knight   When the menace known as the Joker wreaks havo...
# Inception         A thief, who steals corporate secrets through ...
# Kimi no na wa     Two strangers find themselves linked in a biza...
# Dangal            Former wrestler Mahavir Singh Phogat and his t...
# The Intouchables  After he becomes a quadriplegic from a paragli...
#
#                            Director  \
# Title
# Interstellar      Christopher Nolan
# The Dark Knight   Christopher Nolan
# ...

# %% [markdown]
# Multiple Conditions: |==OR      &==AND

# %%
# print movies where James Gunn is Director

# df_name[condition]    condition: df_name['Director']=='James Gunn'

movies_df[movies_df['Director']=='James Gunn']
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
# Slither                   909     Comedy,Horror,Sci-Fi
# Super                     938             Comedy,Drama
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Slither                  A small town is taken over by an alien plague,...
# Super                    After his wife falls under the influence of a ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
# Slither                  James Gunn
# Super                    James Gunn
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Slither                  Nathan Fillion, Elizabeth Banks, Michael Rooke...
# ...

# %%
# List movies og James Gunn with greater than 7 as rating
# condition: Director='James Gunn'  & 'Rating'<7

#        [               (condition1)          &     (condition2)         ]
movies_df[(movies_df['Director']=='James Gunn')& (movies_df['Rating']>7)]
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0

# %%
# List movies between the years 2010 to 2013

# %%
# List movies between the years 2011 to 2015 with rating > 8

# %%
# List movies between 2008 to 2014 with rating >7 and revenue >250

# %%
# Calculate the average rating
avg_rating = movies_df['Rating'].mean()
avg_rating
# Out:
# 6.723199999999999

# %%
# show max rating
max_rating = movies_df['Rating'].max()
max_rating
# Out:
# 9.0

# %%
# show the movie details where rating = 9
movies_df[movies_df['Rating']==9]
# Out:
#                  Rank               Genre  \
# Title
# The Dark Knight    55  Action,Crime,Drama
#
#                                                        Description  \
# Title
# The Dark Knight  When the menace known as the Joker wreaks havo...
#
#                           Director  \
# Title
# The Dark Knight  Christopher Nolan
#
#                                                             Actors  Year  \
# Title
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#                  Runtime (Minutes)  Rating    Votes  Revenue (Millions)  \
# Title
# The Dark Knight                152     9.0  1791916              533.32
#
#                  Metascore
# Title
# The Dark Knight       82.0

# %%
# show max revenue
max_revenue = movies_df['Revenue (Millions)'].max()
max_revenue
# Out:
# 936.63

# %%
# show movie with max revenue
movies_df[movies_df['Revenue (Millions)']==max_revenue]
# Out:
#                                             Rank                     Genre  \
# Title
# Star Wars: Episode VII - The Force Awakens    51  Action,Adventure,Fantasy
#
#                                                                                   Description  \
# Title
# Star Wars: Episode VII - The Force Awakens  Three decades after the defeat of the Galactic...
#
#                                                Director  \
# Title
# Star Wars: Episode VII - The Force Awakens  J.J. Abrams
#
#                                                                                        Actors  \
# Title
# Star Wars: Episode VII - The Force Awakens  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...
#
#                                             Year  Runtime (Minutes)  Rating  \
# Title
# Star Wars: Episode VII - The Force Awakens  2015                136     8.1
#
#                                              Votes  Revenue (Millions)  \
# Title
# ...

# %% [markdown]
# ## Group by Function:

# %%
# group movies by director and also calculate average rating of each director
movies_df.groupby('Director')['Rating'].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %%
#Display the top 5 directors with highest average rating
# for sorting:  ASCENDING: sort_values()    DESCENDING: sort_values(ascending=False)
#          groupby(directors)==find mean rating==sort them in descending==display first 5
movies_df.groupby('Director')['Rating'].mean().sort_values(ascending=False).head(5)
# Out:
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
# Name: Rating, dtype: float64

# %%
## Display highest avg revenue of the top 5 years
## Group Data : ('Year')
## condition : 'Revenue'.mean()
## sort : descending order ==  sort_values(Acending=False)
## Display: first 5 years == head()
movies_df.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False).head()
# Out:
# Year
# 2009    112.601277
# 2012    107.973281
# 2010    105.081579
# 2008     99.082745
# 2007     87.882245
# Name: Revenue (Millions), dtype: float64

# %%
# Find movies with high rating >8 and low revenue <50
# cond1 : movies_df['Rating'] >8
# cond2 : movies_df['Revenue(millions)'<50]
movies_df[(movies_df['Rating']>8.7) & (movies_df['Revenue (Millions)']<50)]
# Out:
#         Rank                   Genre  \
# Title
# Dangal   118  Action,Biography,Drama
#
#                                               Description       Director  \
# Title
# Dangal  Former wrestler Mahavir Singh Phogat and his t...  Nitesh Tiwari
#
#                                                    Actors  Year  \
# Title
# Dangal  Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
#
#         Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# Title
# Dangal                161     8.8  48969               11.15        NaN

# %%
# Which genre generated max avg.revenue . Print the top 10 genres

# %%
# Arrange movies based on genres to display avg  runtime and avg revenue in each genre

# %% [markdown]
# # **What is Matplotlib?**
# Matplotlib is a popular Python library for displaying data and creating static, animated, and interactive plots. This program lets you draw appealing and informative graphics like line plots, scatter plots, histograms, and bar charts.
#
# Matplotlib is highly customizable and flexible, which makes it a preferred choice for data analysts and scientists working in fields such as finance, science, engineering, and social sciences.

# %% [markdown]
# * Matplotlib is an open-source drawing library that supports various drawing types
# * You can generate plots, histograms, bar charts, and other types of charts with just a few lines of code
# * It’s often used in web application servers, shells, and Python scripts

# %% [markdown]
# ## **Getting Started With Pyplot**
# Pyplot is a Matplotlib module that provides simple functions for adding plot elements, such as lines, images, text, etc. to the axes in the current figure.

# %% [markdown]
# ## **Dataset:**
#
#  For this class, we will use the Dow Jones Industrial Average (DJIA) index’s historical prices from 2024-03-22 to 2024-06-20 ([Click here](https://www.wsj.com/market-data/quotes/index/DJIA/historical-prices)). You can set the date range on the page and then click the “download a spreadsheet” button.
#
# The Dow Jones Industrial Average, Dow Jones, or simply the Dow, is a stock market index of 30 prominent companies listed on stock exchanges in the United States. The DJIA is one of the oldest and most commonly followed equity indexes.
